# %% [markdown]
# # Data Analysis

# %%
import cudf

# %%
df_i80 = cudf.read_csv("Cleaned_NGSIM/cleaned_ngsim_i-80.csv")
df_lankershim = cudf.read_csv("Cleaned_NGSIM/cleaned_ngsim_lankershim.csv")
df_peachtree = cudf.read_csv("Cleaned_NGSIM/cleaned_ngsim_peachtree.csv")
df_us101 = cudf.read_csv("Cleaned_NGSIM/cleaned_ngsim_us-101.csv")

# %%
print(df_i80)
# Out:
#          Vehicle_ID  Frame_ID    Global_Time  Local_X_m   Local_Y_m  \
# 0              1859      8279  1113438392800   9.155582  443.640362
# 1              2395     10277  1113438592600  12.701930  408.883409
# 2              1801      7164  1113438281300  13.077139  239.610595
# 3              2174      8380  1113438402900  16.426586  112.682426
# 4              2344      7069  1113437473800  16.238525  185.234885
# ...             ...       ...            ...        ...         ...
# 4349769         824      3458  1113437910700   8.748370  172.990764
# 4349770        1209      3573  1113433492200   5.565038  170.492623
# 4349771        2189      7190  1113433853900   9.206179  426.598994
# 4349772        1454      4567  1113437223600  16.659454  251.893121
# 4349773        1367      3839  1113437150800  24.765914  140.405815
#
#          v_Vel_mps  v_Acc_mps2  Lane_ID  Preceding  Following  Space_Headway  \
# ...

# %%
unique_count = df_i80['Lane_ID'].nunique()
print(f"Number of unique values in 'Lane_ID': {unique_count}")
# Out:
# Number of unique values in 'Lane_ID': 7
