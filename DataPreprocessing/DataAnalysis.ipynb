# %% [markdown]
# # Data Analysis

# %%
import cudf

# %%
df_i80 = cudf.read_csv("Cleaned_NGSIM/cleaned_ngsim_i-80.csv")
df_lankershim = cudf.read_csv("Cleaned_NGSIM/cleaned_ngsim_lankershim.csv")
df_peachtree = cudf.read_csv("Cleaned_NGSIM/cleaned_ngsim_peachtree.csv")
df_us101 = cudf.read_csv("Cleaned_NGSIM/cleaned_ngsim_us-101.csv")

# %%
print(df_i80)
# Out:
#          Vehicle_ID  Frame_ID    Global_Time  Local_X_m   Local_Y_m  \
# 0              2624      8530  1113437619900   1.210056  144.295978
# 1              2775      8231  1113437590000  19.848576   34.603030
# 2              2274      8905  1113438455400   5.221834  119.776342
# 3              1758      7369  1113438301800  21.547226  381.165202
# 4              2513      8404  1113437607300   8.741359  309.141571
# ...             ...       ...            ...        ...         ...
# 4349769        1013      3235  1113433458400   4.974336  358.595066
# 4349770         742      3375  1113437902400   8.624621  229.691489
# 4349771        2034      6810  1113437447900  17.608601  352.989794
# 4349772        2236      6970  1113433831900  16.558260  214.353648
# 4349773        1836      5974  1113433732300   8.750503  394.816279
#
#          v_Vel_mps  v_Acc_mps2  Lane_ID  Preceding  Following  Space_Headway  \
# 0        10.664952   -0.030480        1       2622       2633          59.99
# 1         1.539240   -0.478536        6       2758       2809          43.59
# 2         3.048000    0.000000        2       2264       2285          30.83
# 3         7.924800    1.752600        6       1752       1765          67.03
# 4         5.486400    0.000000        3       2519       2538          53.70
# ...            ...         ...      ...        ...        ...            ...
# 4349769  10.634472   -1.380744        2        998       1023          53.37
# 4349770   5.538216    0.000000        3        714        726          48.01
# 4349771   3.429000    0.000000        5       2010       2033          20.53
# 4349772   6.662928    0.417576        5       2205       2259          40.35
# 4349773   9.787128   -3.413760        3       1828       1842         106.64
#
#          Time_Headway  v_length_m Location Direction_Group  Preceding_ID  \
# 0                1.71     5.73024     i-80               1          2622
# 1                8.63     4.05384     i-80               1          2758
# 2                3.08     5.12064     i-80               1          2264
# 3                2.58     4.05384     i-80               1          1752
# 4                2.98     4.20624     i-80               1          2519
# ...               ...         ...      ...             ...           ...
# 4349769          1.53     4.51104     i-80               1           998
# 4349770          2.64     4.35864     i-80               1           714
# 4349771          1.82     4.66344     i-80               1          2010
# 4349772          1.85     4.51104     i-80               1          2205
# 4349773          3.32     4.54152     i-80               1          1828
#
#          Preceding_v_Length
# 0                   4.51104
# 1                   9.99744
# 2                   5.73024
# 3                   4.35864
# 4                   4.81584
# ...                     ...
# 4349769             3.62712
# 4349770             4.51104
# 4349771             4.20624
# 4349772             3.74904
# 4349773            18.68424
#
# [4349774 rows x 17 columns]
