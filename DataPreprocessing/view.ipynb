# %%
import pickle

# %%
with open('graph_snapshots/i-80/train.pkl', 'rb') as f:
    train_data = pickle.load(f)
print(train_data['x'].shape)  # Should be (batch_size, in_len, num_nodes, num_features)
# Out:
# (1767, 30, 70, 3)

# %%
with open('graph_snapshots/i-80/complete_time_series.pkl', 'rb') as f:
    complete_time_series = pickle.load(f)
print(complete_time_series.shape)  # Should be (timesteps, num_nodes, num_features)
# Out:
# (117800, 70, 3)
